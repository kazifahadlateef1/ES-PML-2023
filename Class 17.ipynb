# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

''' download haberman.csv from https://www.kaggle.com/datasets/gilsousa/habermans-survival-data-set'''

#load iris.cse into a pandas dataFrame
iris= pd.read_csv("haberman.csv")
df= pd.read_csv("haberman.csv")

# %%
# code from https://www.kaggle.com/code/rushabhwadkar/eda-haberman-s-cancer-survival-dataset/notebook

# %%
try :
    columnNamesList = ["PatientAge", "PatientYearOperation", "NumberAxillaryNodes", "SurvivalStatus"]
    cancer_data = pd.read_csv('haberman.csv', names=columnNamesList);
    print("Loaded the dataset successfully.")
except(FileNotFoundError):
    print("Make sure you check the path of the file")
except:
    print("An Error occured.")
# Out:
# Loaded the dataset successfully.

# %%
cancer_data.head()
# Out:
#    PatientAge  PatientYearOperation  NumberAxillaryNodes  SurvivalStatus
# 0          30                    64                    1               1
# 1          30                    62                    3               1
# 2          30                    65                    0               1
# 3          31                    59                    2               1
# 4          31                    65                    4               1

# %%
unique_valuesList = list(cancer_data["SurvivalStatus"].unique())
print(cancer_data.info())
print("\nThe Unique values in the class attribute column are : {}".format(unique_valuesList))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   PatientAge            306 non-null    int64
#  1   PatientYearOperation  306 non-null    int64
#  2   NumberAxillaryNodes   306 non-null    int64
#  3   SurvivalStatus        306 non-null    int64
# dtypes: int64(4)
# memory usage: 9.7 KB
# None
#
# The Unique values in the class attribute column are : [1, 2]

# %%
cancer_data["SurvivalStatus"].replace(to_replace = {
    1: "Survived",
    2: "Died"
}, inplace = True)

print(cancer_data.info())
print(cancer_data.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   PatientAge            306 non-null    int64
#  1   PatientYearOperation  306 non-null    int64
#  2   NumberAxillaryNodes   306 non-null    int64
#  3   SurvivalStatus        306 non-null    object
# dtypes: int64(3), object(1)
# memory usage: 9.7+ KB
# None
#        PatientAge  PatientYearOperation  NumberAxillaryNodes
# count  306.000000            306.000000           306.000000
# mean    52.457516             62.852941             4.026144
# std     10.803452              3.249405             7.189654
# min     30.000000             58.000000             0.000000
# 25%     44.000000             60.000000             0.000000
# 50%     52.000000             63.000000             1.000000
# 75%     60.750000             65.750000             4.000000
# ...

# %%
print(cancer_data["SurvivalStatus"].value_counts())
print("\n" + str(cancer_data["SurvivalStatus"].value_counts(normalize = True)))
# Out:
# Survived    225
# Died         81
# Name: SurvivalStatus, dtype: int64
#
# Survived    0.735294
# Died        0.264706
# Name: SurvivalStatus, dtype: float64

# %%
print(cancer_data.isnull().any())
print("--------------------------")
print(cancer_data.count())
# Out:
# PatientAge              False
# PatientYearOperation    False
# NumberAxillaryNodes     False
# SurvivalStatus          False
# dtype: bool
# --------------------------
# PatientAge              306
# PatientYearOperation    306
# NumberAxillaryNodes     306
# SurvivalStatus          306
# dtype: int64

# %%
plt.close()
cancer_data.hist()
plt.figure(figsize=(18,8))
plt.subplot(1, 3, 2)
plt.title("PDF - CDF Plot")

for index, feature in enumerate(list(cancer_data.columns)[:-1]):
    plt.subplot(1, 3, index+1)
    counts, bin_edges = np.histogram(cancer_data[feature], bins = 10, density = True)
    pdf = counts / sum(counts)
    cdf = np.cumsum(pdf)
    plt.plot(bin_edges[1:], pdf)
    plt.plot(bin_edges[1:], cdf)
    plt.xlabel(feature)
    plt.grid()

plt.show()

# %%
plt.close()
plt.figure(figsize=(18,8))
for index, columnY in enumerate(list(cancer_data.columns)[:-1]):
    plt.subplot(1, 3, index+1)
    sns.boxplot(x="SurvivalStatus", y=columnY, data=cancer_data, palette='husl')
    plt.grid()
plt.subplot(1, 3, 2)
plt.title("Box-Plot / Whiskers Plot")
plt.show()

# %%
plt.close()
plt.figure(figsize=(18,8))
for index, columnY in enumerate(list(cancer_data.columns)[:-1]):
    plt.subplot(1, 3, index+1)
    sns.violinplot(x="SurvivalStatus", y=columnY, data=cancer_data)
    plt.grid()
plt.show()

# %%
a = sns.FacetGrid(data=cancer_data, hue="SurvivalStatus", height=4)\
    .map(plt.scatter, "PatientAge", "NumberAxillaryNodes")\
    .add_legend()

b = sns.FacetGrid(data=cancer_data, hue="SurvivalStatus", height=4)\
    .map(plt.scatter, "PatientAge", "PatientYearOperation")\
    .add_legend()

c = sns.FacetGrid(data=cancer_data, hue="SurvivalStatus", height=4)\
    .map(plt.scatter, "NumberAxillaryNodes", "PatientYearOperation")\
    .add_legend()
plt.show()

# %%
plt.close()
sns.pairplot(data=cancer_data, hue="SurvivalStatus", height=5)
plt.grid()
plt.show()

# %%
import plotly.express as px
fig=px.scatter_3d(habersman,x='age',y='Question_year',z='axial_mode',color='survival_status')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14908\3087403565.py in <module>
#       1 import plotly.express as px
# ----> 2 fig=px.scatter_3d(habersman,x='age',y='Question_year',z='axial_mode',color='survival_status')
#       3 fig.show()
#
# NameError: name 'habersman' is not defined

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

''' download iris.cse from https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv'''

#load iris.cse into a pandas dataFrame
iris= pd.read_csv("iris.csv")
df= pd.read_csv("iris.csv")

# %%
import plotly.express as px
fig=px.scatter_3d(habersman,x='age',y='Question_year',z='axial_mode',color='survival_status')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14908\3087403565.py in <module>
#       1 import plotly.express as px
# ----> 2 fig=px.scatter_3d(habersman,x='age',y='Question_year',z='axial_mode',color='survival_status')
#       3 fig.show()
#
# NameError: name 'habersman' is not defined

# %%
import plotly.express as px

# Assuming you have a DataFrame named 'haberman' with the specified columns
fig = px.scatter_3d(haberman, x='age', y='operation_year', z='axial_nodes', color='survival_status')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14908\2786033258.py in <module>
#       2
#       3 # Assuming you have a DataFrame named 'haberman' with the specified columns
# ----> 4 fig = px.scatter_3d(haberman, x='age', y='question_year', z='axial_mode', color='survival_status')
#       5 fig.show()
#
# NameError: name 'haberman' is not defined

# %%
import pandas as pd

# Replace 'your_data.csv' with the actual path to your dataset
haberman = pd.read_csv('iris.csv')

# After reading the dataset, you can use the 'head()' method to display the first few rows
haberman.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import plotly.express as px

# Assuming you have a DataFrame named 'haberman' with the specified columns
fig = px.scatter_3d(haberman, x='Age', y='Operation_Year', z='Axial_Nodes', color='Survival_Status')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14908\3763312278.py in <module>
#       2
#       3 # Assuming you have a DataFrame named 'haberman' with the specified columns
# ----> 4 fig = px.scatter_3d(haberman, x='Age', y='Operation_Year', z='Axial_Nodes', color='Survival_Status')
#       5 fig.show()
#
# ~\anaconda3\lib\site-packages\plotly\express\_chart_types.py in scatter_3d(data_frame, x, y, z, color, symbol, size, text, hover_name, hover_data, custom_data, error_x, error_x_minus, error_y, error_y_minus, error_z, error_z_minus, animation_frame, animation_group, category_orders, labels, size_max, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, log_x, log_y, log_z, range_x, range_y, range_z, title, template, width, height)
# ...

# %%
import pandas as pd

# Replace 'your_data.csv' with the actual path to your dataset
haberman = pd.read_csv('haberman.csv')

# After reading the dataset, you can use the 'head()' method to display the first few rows
haberman.head()
# Out:
#    30  64   1  1.1
# 0  30  62   3    1
# 1  30  65   0    1
# 2  31  59   2    1
# 3  31  65   4    1
# 4  33  58  10    1

# %%
import plotly.express as px

# Assuming you have a DataFrame named 'haberman' with the specified columns
fig = px.scatter_3d(haberman, x='Age', y='Operation_Year', z='Axial_Nodes', color='Survival_Status')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14908\3763312278.py in <module>
#       2
#       3 # Assuming you have a DataFrame named 'haberman' with the specified columns
# ----> 4 fig = px.scatter_3d(haberman, x='Age', y='Operation_Year', z='Axial_Nodes', color='Survival_Status')
#       5 fig.show()
#
# ~\anaconda3\lib\site-packages\plotly\express\_chart_types.py in scatter_3d(data_frame, x, y, z, color, symbol, size, text, hover_name, hover_data, custom_data, error_x, error_x_minus, error_y, error_y_minus, error_z, error_z_minus, animation_frame, animation_group, category_orders, labels, size_max, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, log_x, log_y, log_z, range_x, range_y, range_z, title, template, width, height)
# ...

# %%
#class 17 video 26 minutes

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Iris dataset from Seaborn
iris = sns.load_dataset("iris")

# Create a 3D scatter plot
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Define the three features you want to plot in 3D
feature1 = "sepal_length"
feature2 = "sepal_width"
feature3 = "petal_length"

# Plot the data points
ax.scatter(iris[feature1], iris[feature2], iris[feature3], c=iris["species"].astype("category").cat.codes, cmap="viridis", s=50)

# Set labels for the axes
ax.set_xlabel(feature1)
ax.set_ylabel(feature2)
ax.set_zlabel(feature3)

# Add a color bar to show the species mapping
mappable = plt.cm.ScalarMappable(cmap="viridis")
mappable.set_array(iris["species"].astype("category").cat.codes)
mappable.set_clim(-0.5, 2.5)
color_bar = plt.colorbar(mappable)
color_bar.set_ticks([0, 1, 2])
color_bar.set_ticklabels(iris["species"].unique())

# Show the 3D scatter plot
plt.title("3D Scatter Plot of Iris Dataset")
plt.show()
